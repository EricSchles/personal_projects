# %%
using PyPlot
ts_length = 100
epsilon_values = randn(ts_length)
plot(epsilon_values, "b-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x319262b50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x3196870d0>
